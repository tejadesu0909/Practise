# %%
import pandas as pd

# %%
df = pd.read_table("http://bit.ly/chiporders")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df1 = pd.read_table("http://bit.ly/movieusers")
df1
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
# Seperating by pipe | character and telling explicitly there is no header

df1_ = pd.read_table("http://bit.ly/movieusers", sep="|", header= None, names = (["id", "Age", "Gender", "Profession", "Sal"]))
df1_
# Out:
#       id  Age Gender     Profession    Sal
# 0      1   24      M     technician  85711
# 1      2   53      F          other  94043
# 2      3   23      M         writer  32067
# 3      4   24      M     technician  43537
# 4      5   33      F          other  15213
# ..   ...  ...    ...            ...    ...
# 938  939   26      F        student  33319
# 939  940   32      M  administrator  02215
# 940  941   20      M        student  97229
# 941  942   48      F      librarian  78209
# 942  943   22      M        student  77841
#
# [943 rows x 5 columns]

# %%
df.order_id
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, Length: 4622, dtype: int64

# %%
df["quantity"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 4617    1
# 4618    1
# 4619    1
# 4620    1
# 4621    1
# Name: quantity, Length: 4622, dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.rename(columns={
    "quantity":"Quantity", "item_name":"Item_Name"
}, inplace=True)

# %%
df.columns
# Out:
# Index(['order_id', 'Quantity', 'Item_Name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Replacing multiple columns in a single line.

df.columns = df.columns.str.replace("i", "I")
df.columns
# Out:
# Index(['order_Id', 'QuantIty', 'Item_Name', 'choIce_descrIptIon',
#        'Item_prIce'],
#       dtype='object')

# %%
# Removing columns in a data frame,

df.drop("Item_prIce", axis=1)
# Out:
#       order_Id  QuantIty                              Item_Name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choIce_descrIptIon
# 0                                                   NaN
# 1                                          [Clementine]
# ...

# %%
# How do I sort the series or a data frame. 

movies = pd.read_csv("http://bit.ly/imdbratings")
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.title.sort_values().tail(20)
# Out:
# 483                   Withnail & I
# 920                        Witness
# 65     Witness for the Prosecution
# 970                    Wonder Boys
# 518                 Wreck-It Ralph
# 954                          X-Men
# 248     X-Men: Days of Future Past
# 532             X-Men: First Class
# 871                             X2
# 695              Y Tu Mama Tambien
# 403                     Ying xiong
# 235                        Yip Man
# 96                         Yojimbo
# 280             Young Frankenstein
# 535                          Zelig
# 955               Zero Dark Thirty
# 677                         Zodiac
# 615                     Zombieland
# 526                           Zulu
# 864                          [Rec]
# Name: title, dtype: object

# %%
movies.sort_values(by="title").head(20)
# Out:
#      star_rating                         title content_rating      genre  \
# 542          7.8          (500) Days of Summer          PG-13     Comedy
# 5            8.9                  12 Angry Men      NOT RATED      Drama
# 201          8.1              12 Years a Slave              R  Biography
# 698          7.6                     127 Hours              R  Adventure
# 110          8.3         2001: A Space Odyssey              G    Mystery
# 910          7.5                          2046              R      Drama
# 596          7.7                      21 Grams              R      Crime
# 624          7.7                     25th Hour              R      Crime
# 708          7.6              28 Days Later...              R     Horror
# 60           8.5                      3 Idiots          PG-13     Comedy
# 225          8.1                        3-Iron              R      Crime
# 570          7.8                           300              R     Action
# ...

# %%
movies[movies["duration"]>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies.loc[movies["duration"]>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# Using AND OR conditions to filter the rows. 

movies.loc[(movies.duration>=200) & (movies.genre == "Crime")]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
# If we want to filter same column with different values such as genre has crime or adventure or drama.
# We can use by giving conditions individually, 

movies.loc[(movies.genre == "Drama" )| (movies.genre == "Crime" ) | (movies.genre == "Adventure" )]
# Out:
#      star_rating                        title content_rating      genre  \
# 0            9.3     The Shawshank Redemption              R      Crime
# 1            9.2                The Godfather              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 4            8.9                 Pulp Fiction              R      Crime
# 5            8.9                 12 Angry Men      NOT RATED      Drama
# ..           ...                          ...            ...        ...
# 970          7.4                  Wonder Boys              R      Drama
# 972          7.4               Blue Valentine          NC-17      Drama
# 973          7.4        The Cider House Rules          PG-13      Drama
# 975          7.4  Back to the Future Part III             PG  Adventure
# 978          7.4                  Wall Street              R      Crime
#
#      duration                                        actors_list
# ...

# %%
# Or we can write it in optimistically by writing, 

movies.loc[movies.genre.isin(["Crime", "Drama", "Adventure"])]
# Out:
#      star_rating                        title content_rating      genre  \
# 0            9.3     The Shawshank Redemption              R      Crime
# 1            9.2                The Godfather              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 4            8.9                 Pulp Fiction              R      Crime
# 5            8.9                 12 Angry Men      NOT RATED      Drama
# ..           ...                          ...            ...        ...
# 970          7.4                  Wonder Boys              R      Drama
# 972          7.4               Blue Valentine          NC-17      Drama
# 973          7.4        The Cider House Rules          PG-13      Drama
# 975          7.4  Back to the Future Part III             PG  Adventure
# 978          7.4                  Wall Street              R      Crime
#
#      duration                                        actors_list
# ...

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# In the above data frame , i need only first and second columns.

ufo = pd.read_csv("http://bit.ly/uforeports", usecols=[0,1])
ufo.columns
# Out:
# Index(['City', 'Colors Reported'], dtype='object')

# %%
# Using For loop in pandas DataFrame or Series. 

for i in ufo.City:
    print(i)
# Out:
# Ithaca
# Willingboro
# Holyoke
# Abilene
# New York Worlds Fair
# Valley City
# Crater Lake
# Alma
# Eklutna
# Hubbard
# Fontana
# Waterloo
# Belton
# Keokuk
# Ludington
# Forest Home
# Los Angeles
# Hapeville
# Oneida
# Bering Sea
# Nebraska
# nan
# nan
# Owensboro
# Wilderness
# San Diego
# Wilderness
# Clovis
# Los Alamos
# Ft. Duschene
# South Kingstown
# North Tampa
# Ft. Lee
# Salinas AFB
# Jasper
# Winston-Salem
# Portsmouth
# Dallas
# Huntington Beach
# San Antonio
# Roswell
# New York City
# Merced
# Alice
# Blairsden
# Index
# South Portland
# Oak Lawn
# Dome
# Conroe
# Syracuse
# Miami
# San Deigo
# Minden
# Cleveland
# Espanola
# Oroville
# Oakmont
# Winona
# Gackle
# Madison
# Hayward
# Tacoma
# Baltimore
# Cashmere
# Maywood
# Wexford
# Sioux Falls
# Seattle
# Dell Rapids
# Philadelphia
# Roswell
# Johnston City
# Roswell
# Syracuse
# Richmond
# Las Vegas
# Keeneyville
# Clintwood
# Hazelton
# Minneapolis
# Morehouse
# San Jose
# Raton
# Modesto
# Green Valley
# ...

# %%
# Instead ofusig for loop we can use below filter
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
for i, r in ufo.iterrows():
    print(i, r.City, r["Colors Reported"])
# Out:
# 0 Ithaca nan
# 1 Willingboro nan
# 2 Holyoke nan
# 3 Abilene nan
# 4 New York Worlds Fair nan
# 5 Valley City nan
# 6 Crater Lake nan
# 7 Alma nan
# 8 Eklutna nan
# 9 Hubbard nan
# 10 Fontana nan
# 11 Waterloo nan
# 12 Belton RED
# 13 Keokuk nan
# 14 Ludington nan
# 15 Forest Home nan
# 16 Los Angeles nan
# 17 Hapeville nan
# 18 Oneida nan
# 19 Bering Sea RED
# 20 Nebraska nan
# 21 nan nan
# 22 nan nan
# 23 Owensboro nan
# 24 Wilderness nan
# 25 San Diego nan
# 26 Wilderness nan
# 27 Clovis nan
# 28 Los Alamos nan
# 29 Ft. Duschene nan
# 30 South Kingstown nan
# 31 North Tampa nan
# 32 Ft. Lee nan
# 33 Salinas AFB nan
# 34 Jasper nan
# 35 Winston-Salem nan
# 36 Portsmouth RED
# 37 Dallas nan
# 38 Huntington Beach nan
# 39 San Antonio nan
# 40 Roswell nan
# 41 New York City nan
# 42 Merced nan
# 43 Alice nan
# 44 Blairsden GREEN
# 45 Index nan
# 46 South Portland nan
# 47 Oak Lawn nan
# 48 Dome nan
# 49 Conroe nan
# 50 Syracuse nan
# 51 Miami nan
# 52 San Deigo nan
# 53 Minden nan
# ...

# %%
drinks = pd.read_csv("http://bit.ly//drinksbycountry")
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
import numpy as np 
drinks = drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.describe(include ="all")
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# count           193     193.000000       193.000000     193.000000
# unique          193            NaN              NaN            NaN
# top     Afghanistan            NaN              NaN            NaN
# freq              1            NaN              NaN            NaN
# mean            NaN     106.160622        80.994819      49.450777
# std             NaN     101.143103        88.284312      79.697598
# min             NaN       0.000000         0.000000       0.000000
# 25%             NaN      20.000000         4.000000       1.000000
# 50%             NaN      76.000000        56.000000       8.000000
# 75%             NaN     188.000000       128.000000      59.000000
# max             NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# ...

# %%
# Selecting only object and floar data types.
drinks.describe(include = ["object", "float64"])
# Out:
#             country  total_litres_of_pure_alcohol continent
# count           193                    193.000000       193
# unique          193                           NaN         6
# top     Afghanistan                           NaN    Africa
# freq              1                           NaN        53
# mean            NaN                      4.717098       NaN
# std             NaN                      3.773298       NaN
# min             NaN                      0.000000       NaN
# 25%             NaN                      1.300000       NaN
# 50%             NaN                      4.200000       NaN
# 75%             NaN                      7.200000       NaN
# max             NaN                     14.400000       NaN
